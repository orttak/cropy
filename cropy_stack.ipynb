# %%
from src import cropy as cpy
import glob

# %% [markdown]
# ### Sample searchs

# %%
#find all B02 under target path
glob.glob('target_path2/*/*B02*')
# Out:
# ['target_path2/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B02_subset.tif',
#  'target_path2/S2B_MSIL2A_20180925T080649_N0208_R078_T37SDB_20180925T113341/B02_subset.tif',
#  'target_path2/S2A_MSIL2A_20181030T081041_N0209_R078_T37SEB_20181030T091317/B02_subset.tif',
#  'target_path2/S2A_MSIL2A_20181030T081041_N0209_R078_T37SEA_20181030T091317/B02_subset.tif']

# %%
#if you downdload time series images for T37SDA you can find all
glob.glob('target_path2/*T37SDA*/*B02*')
# Out:
# ['target_path2/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B02_subset.tif']

# %%
glob.glob('sentinel_cog/*/*/*B04*')
# Out:
# ['sentinel_cog/2018-09-10/S2A_37SDA_20180910_0_L2A/S2A_37SDA_20180910_0_L2A__B04.tif',
#  'sentinel_cog/2018-09-15/S2B_37SDA_20180915_0_L2A/S2B_37SDA_20180915_0_L2A__B04.tif']

# %%
glob.glob('target_path3/*/*B04*')
# Out:
# ['target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B04_subset.tif',
#  'target_path3/S2B_MSIL2A_20180925T080649_N0208_R078_T37SDB_20180925T113341/B04_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SEB_20181030T091317/B04_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SEA_20181030T091317/B04_subset.tif']

# %%
glob.glob('target_path3/*T37SDA*/*B*')
# Out:
# ['target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B02_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B08_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B03_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B04_subset.tif']

# %%
folder_list=sorted(glob.glob('target_path3/*T37SDA*/*B*'))

# %%
folder_list
# Out:
# ['target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B02_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B03_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B04_subset.tif',
#  'target_path3/S2A_MSIL2A_20181030T081041_N0209_R078_T37SDA_20181030T091317/B08_subset.tif']

# %% [markdown]
# #### RGB Stack

# %%
# %%time
rgb_stack=cpy.create_stack(imgs_list=[folder_list[2],folder_list[1],folder_list[0]])
# Out:
# CPU times: user 286 ms, sys: 1.38 ms, total: 288 ms
# Wall time: 286 ms

# %%
# %%time
#save image as tif
cpy.save_image(rgb_stack,target_path='S2_rgb_V2.tif')
# Out:
# CPU times: user 397 ms, sys: 268 ms, total: 664 ms
# Wall time: 602 ms
# 'S2_rgb_V2.tif'

# %%
sentinel_list=glob.glob('sentinel_cog/*/*/*B04*')
sentinel_list
# Out:
# ['sentinel_cog/2018-09-10/S2A_37SDA_20180910_0_L2A/S2A_37SDA_20180910_0_L2A__B04.tif',
#  'sentinel_cog/2018-09-15/S2B_37SDA_20180915_0_L2A/S2B_37SDA_20180915_0_L2A__B04.tif']

# %%
# %%time
time_series=cpy.create_stack(imgs_list=sentinel_list,output_dim_name='time')
# Out:
# CPU times: user 180 ms, sys: 3.85 ms, total: 184 ms
# Wall time: 183 ms

# %%
time_series
# Out:
# <xarray.DataArray (time: 2, y: 10980, x: 10980)>
# dask.array<concatenate, shape=(2, 10980, 10980), dtype=float64, chunksize=(1, 1220, 10980), chunktype=numpy.ndarray>
# Coordinates:
#   * time         (time) int64 1 1
#   * y            (y) float64 4.1e+06 4.1e+06 4.1e+06 ... 3.99e+06 3.99e+06
#   * x            (x) float64 4e+05 4e+05 4e+05 ... 5.097e+05 5.097e+05 5.098e+05
#     spatial_ref  int64 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0
#     grid_mapping:  spatial_ref

# %% [markdown]
# ### Create Statistical Stack
# With this function, you can calculate mean,median, min and max values for list of images. If you don't define a numberOfBand list for stac_result, the system calculate all band in your images list.
#
#     You can use as input:
#     > Result of download_subset_image result (from stac_query.download_subset_image)
#     > If you use download_subset_image, you can get stats_result of each band as dictionary.
#
#     From your local directory, you can give tif path as a list or before read with rioxarray and give that list
#     > list of tif files
#     > list of xarray Dataarray
#
#     Methods
#     > mean,median, min and max
#     > statistic_method = 'mean' #default value is mean
#
#     Input and output dim names are importan to stack the data, Algorithm use this variable.
#     >input_dim_name='band' #default value
#     >output_dim_name='time' #default value
#
#     You can define input dtype or system read from first image of your list.
#     >input_dtype= np.uint16 # it shoud be numpy dtype data

# %%
sentinel_list=glob.glob('sentinel_cog/*/*/*B04*')

# %%
sentinel_list
# Out:
# ['sentinel_cog/2018-09-10/S2A_37SDA_20180910_0_L2A/S2A_37SDA_20180910_0_L2A__B04.tif',
#  'sentinel_cog/2018-09-15/S2B_37SDA_20180915_0_L2A/S2B_37SDA_20180915_0_L2A__B04.tif']

# %%
# %%time
mean_image=cpy.calc_img_stat(imgs_list=sentinel_list)
# Out:
# CPU times: user 6.14 s, sys: 1.2 s, total: 7.34 s
# Wall time: 4.87 s

# %%
mean_image
# Out:
# <xarray.DataArray (y: 10980, x: 10980)>
# array([[3037, 2101, 1775, ..., 3604, 3871, 4547],
#        [2153, 2406, 2519, ..., 3415, 3737, 4302],
#        [2191, 2068, 2441, ..., 3401, 3559, 4284],
#        ...,
#        [2961, 2901, 2930, ..., 3993, 4047, 3984],
#        [2952, 2922, 2934, ..., 3932, 4076, 4062],
#        [3009, 2990, 2953, ..., 3923, 4150, 4170]], dtype=uint16)
# Coordinates:
#   * y            (y) float64 4.1e+06 4.1e+06 4.1e+06 ... 3.99e+06 3.99e+06
#   * x            (x) float64 4e+05 4e+05 4e+05 ... 5.097e+05 5.097e+05 5.098e+05
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:  0.0
